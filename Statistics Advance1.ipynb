# %% [markdown]
# Q1. What is the Probability density function?

# %% [markdown]
#  The Probability Density Function provides a way to understand the distribution of probabilities for continuous random variables across their possible values.

# %% [markdown]
# Q2. What are the types of Probability distribution?

# %% [markdown]
# There are main two types -
# Discrete Probability Distributions - Here the outcomes of random variable assume only integer values
# Continuous Probability Distributions - Here the outcomes of random variable assume both integer non-integer values

# %% [markdown]
# Q3. Write a Python function to calculate the probability density function of a normal distribution with
# given mean and standard deviation at a given point.

# %% [markdown]
# Q4. What are the properties of Binomial distribution? Give two examples of events where binomial
# distribution can be applied.

# %% [markdown]
# 1 - It has discrete random variable.
# 2 - Every experiment outcome is binary
# 3- This experiment is perfomed for n trails.
#
# eg - Tossing a coin 10 times, Testing the effectiveness of a new drug on a group of patients where each patient either responds positively (success) or does not (failure). The number of patients responding positively out of a fixed number of trials (patients) can be modeled using a Binomial distribution.

# %% [markdown]
# Q5. Generate a random sample of size 1000 from a binomial distribution with probability of success 0.4
# and plot a histogram of the results using matplotlib.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Parameters
n = 20  # Number of trials
p = 0.4  # Probability of success

# Generate random sample
sample = np.random.binomial(n, p, 1000)

# Plotting histogram
plt.figure(figsize=(8, 6))
plt.hist(sample, bins=range(n + 2), density=True, alpha=0.75, color='blue', edgecolor='black')

# Add labels and title
plt.title('Histogram of Binomial Distribution')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(range(n + 1))
plt.grid(axis='y', alpha=0.75)
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# Q6. Write a Python function to calculate the cumulative distribution function of a Poisson distribution
# with given mean at a given point.

# %% [markdown]
# Q7. How Binomial distribution different from Poisson distribution?

# %%
# It is different because binomial distribution outcome is binary whereas poisson describes the number of events occuring in a fixed time interval.

# %% [markdown]
# Q8. Generate a random sample of size 1000 from a Poisson distribution with mean 5 and calculate the
# sample mean and variance.

# %%
import numpy as np

# Parameters
mean_poisson = 5  # Mean of the Poisson distribution
sample_size = 1000

# Generate random sample from Poisson distribution
sample = np.random.poisson(mean_poisson, sample_size)

# Calculate sample mean and variance
sample_mean = np.mean(sample)
sample_variance = np.var(sample)

print(f"Sample Mean: {sample_mean}")
print(f"Sample Variance: {sample_variance}")
# Out:
# Sample Mean: 5.045
# Sample Variance: 4.994975

# %% [markdown]
# Q9. How mean and variance are related in Binomial distribution and Poisson distribution?

# %% [markdown]
# # In binomial
# mean = np
# variance = npq   where n = no of trials, p = success probability of each trial , failure probability ( 1- p)
#
# # In poisson
# mean and variance are same which is E(x) = expected no of events occur at every time interval * time interval

# %% [markdown]
# Q10. In normal distribution with respect to mean position, where does the least frequent data appear?
